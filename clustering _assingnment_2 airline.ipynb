# %%
import pandas as pd

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
import scipy.cluster.hierarchy as sch

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

# %%
data2=pd.read_excel("D:\\Excelr files\\airlines.xlsx",sheet_name="data")

# %%
data2
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data2.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
data2=data2.drop(['ID#'],axis=1)

# %%
data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#normalise the data
def norm_fun(i):
    x=(i-i.min())/(i.max()-i.min())
    return(x)

# %%
data_norm=norm_fun(data2)

# %%
data_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# now create dendrogram
dendrogram=sch.dendrogram(sch.linkage(data_norm,'complete'))

# %%
h_cluster=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')

# %%
h_cluster
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
model=h_cluster.fit_predict(data_norm)

# %%
model
# Out:
# array([1, 1, 1, ..., 0, 4, 4], dtype=int64)

# %%
cluster=pd.DataFrame(model,columns=['clusters'])

# %%
cluster
# Out:
#       clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            3
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         4
# 3998         4
#
# [3999 rows x 1 columns]

# %%
data2['clusters']=cluster

# %%
data2['clusters']=h_cluster.labels_

# %%
data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data2.groupby('clusters').agg(['mean']).reset_index()
# Out:
#   clusters        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean        mean      mean      mean      mean
# 0        0   79848.233615  285.097252  1.699789  1.024313  1.000000
# 1        1   43313.653808   21.506429  1.000000  1.033630  1.000989
# 2        2  106221.111386  161.262376  3.198020  1.001238  1.025990
# 3        3  127475.028037  160.801869  4.362617  1.000000  1.050467
# 4        4   30013.416309   98.054363  1.000000  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  12079.774841   12.133192        781.939746        2.369979
# 1   2562.614243    5.474777        169.510386        0.523244
# 2  26458.257426   16.363861        198.733911        0.558168
# 3  58656.919626   22.235514        991.110280        3.005607
# 4   2552.569385    6.101574        340.274678        0.948498
#
#   Days_since_enroll Award?
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,7))
plt.scatter(data2['clusters'],data2['Balance'],c=h_cluster.labels_)

# %%
#solving by kmeans
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler

# %%
data3=pd.read_excel("D:\\Excelr files\\airlines.xlsx",sheet_name="data")

# %%
data3
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data3.drop(['ID#'],axis=1)
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
scaler=StandardScaler()

# %%
data3_norm=scaler.fit_transform(data3)

# %%
data3_norm
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
wcss=[]
for i in range (1,25):
    kmeans=KMeans(n_clusters=i,random_state=0)
    kmeans.fit(data3_norm)
    wcss.append(kmeans.inertia_)
    
    
plt.plot(range(1,25),wcss)
plt.title('elbow_method')
plt.xlabel=('clusters')
plt.ylabel=('wcss')
plt.show()                             # elbow method to see how many clusters are form

# %%
new_kmeans=KMeans(5,random_state=40)
new_kmeans.fit(data3_norm)
# Out:
# KMeans(n_clusters=5, random_state=40)

# %%
new_kmeans.labels_
# Out:
# array([2, 2, 2, ..., 0, 0, 0])

# %%
data3['cluster']=new_kmeans.labels_

# %%
data3
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
new_kmeans.cluster_centers_
# Out:
# array([[ 0.96654453, -0.33833611, -0.05237909, -0.50084333,  0.01769875,
#         -0.06276658, -0.45702392, -0.40423281, -0.18777249, -0.20664224,
#         -0.95534184, -0.34702599],
#        [-0.39898482,  0.51834189,  0.02390147,  1.36247185, -0.0849603 ,
#         -0.05272242,  1.1286793 ,  0.79993182, -0.06443532, -0.06981043,
#          0.40191622,  0.68672739],
#        [-0.79229548, -0.16448107, -0.06044523, -0.51205951,  0.02787651,
#         -0.05879255, -0.46839959, -0.37994341, -0.16471941, -0.17582311,
#          0.77198835, -0.25121812],
#        [-0.22708278,  1.20284695,  0.8613124 ,  0.10111012,  0.16228153,
#         -0.06276658,  0.63485991,  1.68030149,  3.607528  ,  3.91562026,
#          0.27255539,  0.93222938],
#        [-0.30152248,  0.63971926, -0.08443292,  1.0220844 , -0.09824189,
#         15.64629931,  3.17969131,  1.71461374,  0.03329269,  0.05969539,
#          0.23987261,  0.33752735]])

# %%
data3.groupby('cluster').agg(['mean']).reset_index()
# Out:
#   cluster          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                   mean           mean        mean      mean      mean
# 0       0  3136.609612   39509.544437  103.595787  1.369980  1.017117
# 1       1  1551.750000  125831.045098  162.603922  3.935294  1.001961
# 2       2  1095.266098   57027.711404   97.356090  1.354538  1.018619
# 3       3  1751.262821  194803.871795  810.397436  2.198718  1.038462
# 4       4  1664.866667  138061.400000   78.800000  3.466667  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000000   6108.656353    7.720211        197.167874        0.589862
# 1  1.001961  44400.135294   19.283333        369.844118        1.108824
# 2  1.000776   5833.957331    7.953452        229.442979        0.706749
# 3  1.000000  32475.410256   27.737179       5510.717949       16.224359
# ...

# %%
plt.figure(figsize=(10,7))
plt.scatter(data3['cluster'],data3['Balance'],c=new_kmeans.labels_)

# %%
#solving by dbscan

# %%
data4=pd.read_excel("D:\\Excelr files\\airlines.xlsx",sheet_name="data")

# %%
data4
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data4.drop(['ID#'],axis=1)
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
scalar=StandardScaler()

# %%
data4_norm=scaler.fit_transform(data4)

# %%
data4_norm
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan=DBSCAN(eps=1,min_samples=5)

# %%
dbscan.fit(data4_norm)
# Out:
# DBSCAN(eps=1)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
data4['cluster']=dbscan.labels_

# %%
data4
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data4.groupby('cluster').agg(['mean']).reset_index()
# Out:
#   cluster          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                   mean           mean         mean      mean      mean
# 0      -1  1754.912226  172701.286834   853.857367  2.644201  1.070533
# 1       0  2182.997378   52526.928759     2.092220  1.658217  1.000000
# 2       1  1793.359121   60233.644699     5.862464  2.606495  1.000000
# 3       2  1263.400000   44500.800000     0.000000  1.000000  1.000000
# 4       3  2557.230769   34806.538462     0.000000  1.000000  2.000000
# 5       4  3215.375000   28382.500000  2578.500000  1.000000  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.076803  37509.277429   21.158307       2067.918495        5.982759
# 1  1.000000   8994.866696    8.428322        113.126748        0.373252
# 2  1.000000  22813.090735   12.769819        236.007641        0.738300
# ...

# %%
plt.figure(figsize=(10,7))
plt.scatter(data4['cluster'],data4['Balance'],c=dbscan.labels_)

# %%
plt.figure(figsize=(10,7))
plt.scatter(data4['cluster'],data4['Award?'],c=dbscan.labels_)
